# %% [markdown]
# # Zomato Dataset Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('zomato.csv')
df.head()

# %%
df.info()
df.describe(include='all')

# %%
df.isnull().sum()

# %% [markdown]
# ## Visualizations
# 1. Top Locations
# 2. Rating Distribution
# 3. Cost vs Rating
# 4. Correlation Heatmap

# %% [markdown]
# ## Conclusion
# Popular cuisines and locations dominate the dataset. Moderate pricing with good service receives better ratings.
